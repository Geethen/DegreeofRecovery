# %%
import ee

# %%
try:
    ee.Initialize(project="ee-gsingh")
except Exception as e:
    print(e)
    ee.Authenticate(auth_mode="notebook")
    ee.Initialize(project="ee-gsingh")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
samples = ee.FeatureCollection("projects/nina/RECOVER/samples_recover_w_ref_label")
samples.size()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
# ...

# %%
import pandas as pd

df = pd.read_parquet(
    r"C:\Users\geethen.singh\degreeRecover\v1\data\recover_reference_samples_alphaearth.parquet"
)
df = pd.read_parquet(
    r"C:\Users\geethen.singh\degreeRecover\v1\data\test_site_alphaearth_2024.parquet"
)
df
# Out:
#                 parent_id       A00       A01       A02       A03       A04  \
# 0    00000000000000000001 -0.004983  0.032541  0.119093  0.032541 -0.179377
# 1    00000000000000000049 -0.022207  0.001538  0.088827 -0.066990 -0.066990
# 2    0000000000000000004a -0.088827 -0.301423 -0.055363 -0.292872 -0.012057
# 3    0000000000000000004f  0.192910  0.147697 -0.003937 -0.035433  0.214133
# 4    0000000000000000005a  0.013841 -0.079723  0.113741 -0.153787  0.048228
# ..                    ...       ...       ...       ...       ...       ...
# 153  000000000000000006c0 -0.098424  0.130165 -0.071111  0.075356 -0.055363
# 154  000000000000000006cc  0.062991 -0.075356  0.071111 -0.012057  0.214133
# 155  000000000000000006ce -0.206936  0.166336  0.166336 -0.027128 -0.214133
# 156  000000000000000006d9 -0.071111 -0.062991 -0.292872 -0.192910  0.141730
# 157  000000000000000006e5 -0.147697  0.084214  0.166336  0.172795 -0.147697
#
# ...
